# %%
# !pip install -r ./requirements.txt

# %%
"""
Exemplo 1: Uso básico com dry-run e execução real
"""

from sqlalchemy import create_engine
from csv_ingestion import CsvToDatabaseLoader
from glob import glob

path = r"R:\\GEPPI\\COPPI\\PELT\\PELTMG_LP\\Indicadores avaliativos\\Emissões\\tbl_alocacao\\*.csv"

# Configurar conexão com o banco
# Substitua com suas credenciais reais
DATABASE_URL = "postgresql+psycopg2://usuario:senha@localhost:5432/meu_banco"

# Criar engine
engine = create_engine(DATABASE_URL)

start = True
for path_file in sorted(glob(path), key=lambda x: int(x.split("\\")[-1].split(".")[0]))[1:]:
    # Criar loader
    loader = CsvToDatabaseLoader(
        engine=engine,
        csv_path=path_file,
        schema="visum_peltlp",
        table_name="tbl_emissoes_v2",
        create_table=start,          # ← CRIA AUTOMATICAMENTE
        if_exists="append",        # ou "replace" ou "fail"
        chunk_size=100000,
    )
    start = False

    # Etapa 2: Executar inserção real
    print("\\n💾 Executando INSERÇÃO REAL...\\n")
    report = loader.run(dry_run=False)

    print(f"\n✅ Inserção concluída!")
    print(f"   Linhas inseridas: {report.rows_inserted}")
    print(f"   Duração: {report.duration_seconds:.2f}s")

# %%
# Out:
# ['R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\101.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\102.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\103.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\104.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\105.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\106.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\107.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\108.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\109.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\110.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\111.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\112.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\113.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\114.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\115.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\116.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\117.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\118.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\119.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\201.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\202.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\203.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\204.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\205.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\206.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\207.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\208.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\209.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\210.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\211.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\212.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\213.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\214.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\215.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\216.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\217.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\301.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\302.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\303.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\304.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\401.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\402.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\403.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\404.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\405.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\501.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\601.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\602.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\603.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\701.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\801.csv',
#  'R:\\\\GEPPI\\\\COPPI\\\\PELT\\\\PELTMG_LP\\\\Indicadores avaliativos\\\\Emissões\\\\tbl_alocacao\\802.csv']
